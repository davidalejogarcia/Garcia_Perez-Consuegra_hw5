# %% [markdown]
# # Ejercicio 3
#
# Metodos Computacionales
# Por: David Alejandro Garcia y Nicolas Perez Consuegra

# %% [markdown]
# ## Enunciado: En el archivo circulos.dat se encuentran posiciones en un plano x − y. Estos puntos corresponden a la superposicion de diferentes cırculos mas un fondo de puntos distribuidos aleatoriamente a partir de una distribucion homogenea. Escriba un programa en python que encuentre el di ́ametro de estos c ́ırculos utilizando metodos de transformada de Fourier.

# %%
# %pylab inline
import matplotlib.pyplot as plt
import numpy as np
from scipy.fftpack import fft, fftfreq, fft2
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Aqui se lee el archivo circulos.dat y se lee por lineas. Luego se cierra el archivo

# %%
f = open('circulos.dat', 'r') 
lines = f.readlines() #http://www.tutorialspoint.com/python/file_readlines.htm
f.close()

# %% [markdown]
# ## Aqui voy a crear 3 listas: x1,y1,a y hacerles un append - introducirles a x1 la primera columna, a y1 la segunda columna y en a voy a agregar ambas columnas.

# %%
 x1 = []
y1 = []
a=[]

# %%
for line in lines:
    p = line.split()
    x1.append(float(p[0]))
    y1.append(float(p[1]))
    a.append([float(p[0]),float(p[1])])

# %% [markdown]
# ## Aqui hago un scatter para ver los puntos, que me generan circulos distribuidos por todo el recuadro.

# %%
plt.scatter(x1,y1,s=0.1)

# %% [markdown]
# ## Lo siguiente es definir un valor de pixel. Para esto tomo el valor maximo y minimo de las listas creadas anteriormente, resto estos valores para x1 y y1 respectivamente y luego divido el resultado sobre un numero de puntos arbitrarios. Luego creo una lista en 2D de n_ponts x n_ponts y esto me genera diferentes espacios en donde voy a guardar informacion.

# %%
n_ponts=100
delx=(np.amax(x1)-np.amin(x1))/n_ponts
dely=(np.amax(y1)-np.amin(y1))/n_ponts
size(y1)
# Out:
# 29010

# %% [markdown]
# ## En cada uno de nos cuadros o pixeles voy asignar el numero de puntos que caen adentro del mismo pixel. Para hacer esto recorro las listas x1 y y1 mirando en que pixel caen.

# %%
a = numpy.empty((n_ponts, n_ponts))
a1=np.amin(x1)
a2=np.amin(y1)
b1=a1+delx
b2=a2+dely
for h in range(n_ponts):
    for i in range(n_ponts):
        hay=0
        for j in range(size(x1)):
            if x1[j]<b1 and y1[j]<b2 and x1[j]>=a1 and y1[j]>=a2:
                hay=hay+1
        a[i][h]=hay
        a1=a1+delx
        b1=a1+delx
    a1=np.amin(x1)
    b1=a1+delx
    a2=a2+dely
    b2=a2+dely
        
print hay
# Out:
# 4

# %% [markdown]
# ## Aca hago el plot de la imagen de frecuencias?. Es decir hago un cmap con los valores en la lista a de n_ponts x n_ponts pixeles.

# %%
imshow(a[:,:], cmap = cm.Greys_r)

# %% [markdown]
# ## Aqui se realiza la transformada de Fourier del array 2D 'a'

# %%
fft_points = fft2(a)
r,c = shape(fft_points)
x = linspace(0,c-1,c)
y = linspace(0,r-1,r)

# %%
plt.scatter(x,y, abs(fft_points))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.imshow(np.abs(fft_points))
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f5ab28fda70>

# %%
F_Transform=fft_points
ff_order = F_Transform.copy()

size_filas = r # Gives the number of rows in the 2d Array
size_columnas = c# Gives the number of columns in the 2d Array

ff_order[ size_filas/2:size_filas , size_columnas/2:size_columnas ] = F_Transform[0:size_filas/2 , 0:size_columnas/2]
ff_order[ 0:size_filas/2 , 0:size_columnas/2] = F_Transform[size_filas/2:size_filas , size_columnas/2:size_columnas ]
ff_order[ 0:size_filas/2 , size_columnas/2:size_columnas ] = F_Transform[size_filas/2:size_filas , 0:size_columnas/2]
ff_order[size_filas/2:size_filas , 0:size_columnas/2] = F_Transform[0:size_filas/2 , size_columnas/2:size_columnas ]

# %%
plt.imshow(np.abs(ff_order))

# %%
size(ff_order[:][0])
# Out:
# 100

# %%
plot (ff_order[:][50])
# Out:
# /usr/lib/python2.7/dist-packages/numpy/core/numeric.py:460: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
#Autocorrelation
fft_corr = fft2(abs(a)**2)
plt.imshow(np.abs(fft_corr))

# %%
F_Transform=fft_corr
ff_order = F_Transform.copy()

size_filas = r # Gives the number of rows in the 2d Array
size_columnas = c# Gives the number of columns in the 2d Array

ff_order[ size_filas/2:size_filas , size_columnas/2:size_columnas ] = F_Transform[0:size_filas/2 , 0:size_columnas/2]
ff_order[ 0:size_filas/2 , 0:size_columnas/2] = F_Transform[size_filas/2:size_filas , size_columnas/2:size_columnas ]
ff_order[ 0:size_filas/2 , size_columnas/2:size_columnas ] = F_Transform[size_filas/2:size_filas , 0:size_columnas/2]
ff_order[size_filas/2:size_filas , 0:size_columnas/2] = F_Transform[0:size_filas/2 , size_columnas/2:size_columnas ]

# %%
plt.imshow(np.abs(ff_order))

# %%
n_points=100
Radii=zeros(n_points/2)
for h in range(n_points/2):
    for i in range(n_points):
        for j in range(n_points):
            nor=sqrt((i-50)**2+(j-50)**2)
            if nor<=h+1 and nor>h:
                Radii[h]=Radii[h]+abs(ff_order[i,j])

# %%
plot(Radii)
#http://mathworld.wolfram.com/Wiener-KhinchinTheorem.html
#http://mathworld.wolfram.com/Autocorrelation.html

# %%
a=Radii
b = numpy.r_[True, a[1:] < a[:-1]] & numpy.r_[a[:-1] < a[1:], True]
print b
# Out:
# [False False  True False False False  True False False False  True False
#  False False  True False False False  True False False False  True False
#  False  True False False False  True False False False  True False False
#  False  True False False  True False False False  True False False False
#   True False]

# %%
print b[1]
# Out:
# False

# %%
cont = 0
for i in range(len(b)):
    if(b[i] == True):
        cont = cont + 1
        
contador = []
for i in range(cont):
    contador.append(i)

# %%
    
cont = 0

for i in range(len(b)):
 if (b[i] == True):
  contador[cont] = i
  cont = cont + 1

# %%
print contador
# Out:
# [2, 6, 10, 14, 18, 22, 25, 29, 33, 37, 40, 44, 48]

# %%
s = []
for i in range(cont-1):
    s.append(i)

for i in range(0,cont-1):
    s[i] = abs(contador[i] - contador[i+1])

# %%
print s
# Out:
# [4, 4, 4, 4, 4, 3, 4, 4, 4, 3, 4, 4]

# %%
plot(s)
1.0/s[0]
# Out:
# 0.25

# %%
for i in range(0,cont-1):
    s[i] = 1.0 / s[i]
print s
# Out:
# [0.25, 0.25, 0.25, 0.25, 0.25, 0.3333333333333333, 0.25, 0.25, 0.25, 0.3333333333333333, 0.25, 0.25]

# %%
promedio = 0.0
n_points = 0.0

for i in range(0,cont-1):
    promedio = promedio + s[i]
    n_points = n_points +1
    
promedio = promedio/n_points

# %%
print promedio
# Out:
# 0.263888888889
